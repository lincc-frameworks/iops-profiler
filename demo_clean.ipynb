# %%
# %load_ext iops_profiler

# %%
# %%iops --histogram
# import numpy as np
# import pandas as pd
#
# # Generate and save random data
# data = pd.DataFrame(np.random.randn(100000, 3))
# data.to_parquet('data.parquet')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 import numpy as np
# ----> 2 import pandas as pd
#       4 # Generate and save random data
#       5 data = pd.DataFrame(np.random.randn(100000, 3))
#
# ModuleNotFoundError: No module named 'pandas'
#     <style>
#         .iops-table {
#             border-collapse: collapse;
#             margin: 10px 0;
#             font-family: monospace;
#             font-size: 14px;
#         }
#         .iops-table td {
#             padding: 6px 12px;
#             border: 1px solid #ddd;
#         }
#         .iops-table tr:first-child td {
#             background-color: #f5f5f5;
#             font-weight: bold;
#         }
#         .iops-warning {
#             color: #ff6600;
#             font-size: 12px;
#             margin-top: 5px;
#         }
#     </style>
#     <div>
#         <table class="iops-table">
#             <tr>
#                 <td colspan="2">IOPS Profile Results (strace (per-process))</td>
#             </tr>
#             <tr>
#                 <td>Execution Time</td>
#                 <td>0.6600 seconds</td>
#             </tr>
#             <tr>
#                 <td>Read Operations</td>
#                 <td>17</td>
#             </tr>
#             <tr>
#                 <td>Write Operations</td>
#                 <td>2</td>
#             </tr>
#             <tr>
#                 <td>Total Operations</td>
#                 <td>19</td>
#             </tr>
#             <tr>
#                 <td>Bytes Read</td>
#                 <td>108.02 KB (110,608 bytes)</td>
#             </tr>
#             <tr>
#                 <td>Bytes Written</td>
#                 <td>16.00 B (16 bytes)</td>
#             </tr>
#             <tr>
#                 <td>Total Bytes</td>
#                 <td>108.03 KB (110,624 bytes)</td>
#             </tr>
#             <tr>
#                 <td><strong>IOPS</strong></td>
#                 <td><strong>28.79 operations/second</strong></td>
#             </tr>
#             <tr>
#                 <td><strong>Throughput</strong></td>
#                 <td><strong>163.69 KB/second</strong></td>
#             </tr>
#         </table>
#     </div>
