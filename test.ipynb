# %%
# %load_ext iops_profiler

# %%
# %%iops
# import os
# f = open("test.txt", 'w')
# f.write("stuff" * 100)  # Write data
# f.write("stuff" * 100)  # Write more data
# f.close()
# Out:
# ⚠️  A password dialog will appear - please enter your password to enable I/O monitoring.
#         <style>
#             .iops-table {
#                 border-collapse: collapse;
#                 margin: 10px 0;
#                 font-family: monospace;
#                 font-size: 14px;
#             }
#             .iops-table td {
#                 padding: 6px 12px;
#                 border: 1px solid #ddd;
#             }
#             .iops-table tr:first-child td {
#                 background-color: #f5f5f5;
#                 font-weight: bold;
#             }
#             .iops-warning {
#                 color: #ff6600;
#                 font-size: 12px;
#                 margin-top: 5px;
#             }
#         </style>
#         <div>
#             <table class="iops-table">
#                 <tr>
#                     <td colspan="2">IOPS Profile Results (fs_usage (per-process))</td>
#                 </tr>
#                 <tr>
# ...

# %%
import lsdb

# %%
catalog = lsdb.open_catalog("https://data.lsdb.io/hats/erosita", columns=["RA", "DEC"])
catalog
# Out:
# Dask NestedFrame Structure:
#                                   RA              DEC
# npartitions=10
# 288230376151711744   double[pyarrow]  double[pyarrow]
# 576460752303423488               ...              ...
# ...                              ...              ...
# 3170534137668829184              ...              ...
# 3458764513820540928              ...              ...
# Dask Name: nestedframe, 3 expressions
# Expr=MapPartitions(NestedFrame)

# %%
# %%iops
# catalog.to_hats(base_catalog_path="./my_catalog", catalog_name="my_catalog", overwrite=True)
# Out:
# ⚠️  A password dialog will appear - please enter your password to enable I/O monitoring.
#         <style>
#             .iops-table {
#                 border-collapse: collapse;
#                 margin: 10px 0;
#                 font-family: monospace;
#                 font-size: 14px;
#             }
#             .iops-table td {
#                 padding: 6px 12px;
#                 border: 1px solid #ddd;
#             }
#             .iops-table tr:first-child td {
#                 background-color: #f5f5f5;
#                 font-weight: bold;
#             }
#             .iops-warning {
#                 color: #ff6600;
#                 font-size: 12px;
#                 margin-top: 5px;
#             }
#         </style>
#         <div>
#             <table class="iops-table">
#                 <tr>
#                     <td colspan="2">IOPS Profile Results (fs_usage (per-process))</td>
#                 </tr>
#                 <tr>
# ...
