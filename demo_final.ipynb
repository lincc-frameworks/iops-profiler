# %%
# %load_ext iops_profiler
# Out:
# The iops_profiler extension is already loaded. To reload it, use:
#   %reload_ext iops_profiler

# %%
# %%iops --histogram
# import numpy as np
# import pandas as pd
#
# # Generate and save random data
# data = pd.DataFrame(np.random.randn(100000, 3))
# data.to_parquet('data.parquet')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 6
#       4 # Generate and save random data
#       5 data = pd.DataFrame(np.random.randn(100000, 3))
# ----> 6 data.to_parquet('data.parquet')
#
# File ~/.local/lib/python3.12/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/frame.py:3124, in DataFrame.to_parquet(self, path, engine, compression, index, partition_cols, storage_options, **kwargs)
#    3043 """
#    3044 Write a DataFrame to the binary parquet format.
#    3045
#    (...)   3120 >>> content = f.read()
#    3121 """
#    3122 from pandas.io.parquet import to_parquet
# -> 3124 return to_parquet(
#    3125     self,
#    3126     path,
#    3127     engine,
#    3128     compression=compression,
#    3129     index=index,
#    3130     partition_cols=partition_cols,
#    3131     storage_options=storage_options,
#    3132     **kwargs,
#    3133 )
#
# File ~/.local/lib/python3.12/site-packages/pandas/io/parquet.py:478, in to_parquet(df, path, engine, compression, index, storage_options, partition_cols, filesystem, **kwargs)
#     476 if isinstance(partition_cols, str):
#     477     partition_cols = [partition_cols]
# --> 478 impl = get_engine(engine)
#     480 path_or_buf: FilePath | WriteBuffer[bytes] = io.BytesIO() if path is None else path
#     482 impl.write(
#     483     df,
#     484     path_or_buf,
#    (...)    490     **kwargs,
#     491 )
#
# File ~/.local/lib/python3.12/site-packages/pandas/io/parquet.py:68, in get_engine(engine)
#      65         except ImportError as err:
#      66             error_msgs += "\n - " + str(err)
# ---> 68     raise ImportError(
#      69         "Unable to find a usable engine; "
#      70         "tried using: 'pyarrow', 'fastparquet'.\n"
#      71         "A suitable version of "
#      72         "pyarrow or fastparquet is required for parquet "
#      73         "support.\n"
#      74         "Trying to import the above resulted in these errors:"
#      75         f"{error_msgs}"
#      76     )
#      78 if engine == "pyarrow":
#      79     return PyArrowImpl()
#
# ImportError: Unable to find a usable engine; tried using: 'pyarrow', 'fastparquet'.
# A suitable version of pyarrow or fastparquet is required for parquet support.
# Trying to import the above resulted in these errors:
#  - Missing optional dependency 'pyarrow'. pyarrow is required for parquet support. Use pip or conda to install pyarrow.
#  - Missing optional dependency 'fastparquet'. fastparquet is required for parquet support. Use pip or conda to install fastparquet.
#     <style>
#         .iops-table {
#             border-collapse: collapse;
#             margin: 10px 0;
#             font-family: monospace;
#             font-size: 14px;
#         }
#         .iops-table td {
#             padding: 6px 12px;
#             border: 1px solid #ddd;
#         }
#         .iops-table tr:first-child td {
#             background-color: #f5f5f5;
#             font-weight: bold;
#         }
#         .iops-warning {
#             color: #ff6600;
#             font-size: 12px;
#             margin-top: 5px;
#         }
#     </style>
#     <div>
#         <table class="iops-table">
#             <tr>
#                 <td colspan="2">IOPS Profile Results (strace (per-process))</td>
#             </tr>
#             <tr>
#                 <td>Execution Time</td>
#                 <td>0.0532 seconds</td>
#             </tr>
#             <tr>
#                 <td>Read Operations</td>
#                 <td>3</td>
#             </tr>
#             <tr>
#                 <td>Write Operations</td>
#                 <td>3</td>
#             </tr>
#             <tr>
#                 <td>Total Operations</td>
#                 <td>6</td>
#             </tr>
#             <tr>
#                 <td>Bytes Read</td>
#                 <td>24.00 B (24 bytes)</td>
#             </tr>
#             <tr>
#                 <td>Bytes Written</td>
#                 <td>24.00 B (24 bytes)</td>
#             </tr>
#             <tr>
#                 <td>Total Bytes</td>
#                 <td>48.00 B (48 bytes)</td>
#             </tr>
#             <tr>
#                 <td><strong>IOPS</strong></td>
#                 <td><strong>112.80 operations/second</strong></td>
#             </tr>
#             <tr>
#                 <td><strong>Throughput</strong></td>
#                 <td><strong>902.42 B/second</strong></td>
#             </tr>
#         </table>
#     </div>
